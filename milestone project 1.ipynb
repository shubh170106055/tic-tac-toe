# %%
def tiktok():
    wannaplay = input('do u want to play : ')
    if wannaplay == 'yes':
        sign = input('choose your sign x or o : ')
        if sign == 'x':
            othersign = 'o'
            print ('othersign = o')
        elif sign == 'o':
            othersign = 'x'
            print ('othersign = x')
        else :
            print ('plz choose btxn x and o')
            tiktok()
    elif wannaplay == 'no':
        print ('see you later ')
    else :
        print ('valid entry please : ')
        tiktok()
    
    l = ['a',' ',' ',' ',' ',' ',' ',' ',' ',' ']
    def board():
             print('{} | {} | {}'.format(l[1],l[2],l[3]))
             print('_____________')
                
             print('{} | {} | {}'.format(l[4],l[5],l[6]))
             print('_____________')
                
             print('{} | {} | {}'.format(l[7],l[8],l[9]))      
    def checkifwin(): 
        a = 0
        if ((l[1]=='x'or l[1]=='o')) and ((l[1]==l[2]==l[3]) or (l[1]==l[5]==l[9]) or (l[1]==l[4]==l[7])) :
              a = 1
        elif ((l[4]=='x'or l[4]=='o')) and ((l[4]==l[5]==l[6]) or (l[1]==l[4]==l[7])) :
              a = 1
        elif ((l[7]=='x'or l[7]=='o')) and ((l[7]==l[8]==l[9]) or (l[7]==l[5]==l[3]) or (l[1]==l[4]==l[7])) :
              a = 1
        elif ((l[2]=='x'or l[2]=='o')) and ((l[1]==l[2]==l[3]) or (l[2]==l[5]==l[8])) :
              a = 1 
        elif ((l[5]=='x'or l[5]=='o')) and ((l[4]==l[5]==l[6]) or (l[1]==l[5]==l[9]) or (l[3]==l[5]==l[7]) or (l[5]==l[2]==l[8])):
              a = 1
        elif ((l[8]=='x'or l[8]=='o')) and ((l[7]==l[8]==l[9]) or (l[2]==l[5]==l[8])) :
              a = 1
        elif ((l[3]=='x'or l[3]=='o')) and ((l[1]==l[2]==l[3]) or (l[3]==l[6]==l[9]) or (l[3]==l[5]==l[7])) :
              a = 1
        elif ((l[6]=='x'or l[6]=='o')) and ((l[9]==l[6]==l[3]) or (l[4]==l[5]==l[6])) :
              a = 1
        elif ((l[9]=='x'or l[9]=='o')) and ((l[7]==l[8]==l[9]) or (l[3]==l[6]==l[9]) or (l[1]==l[5]==l[9])) :
              a = 1
        else :
              a = 0
        return a     
    b = 1
    m = []
    
    while b < 10 : 
        if b%2 != 0 :
            c = 1
        else :
            c = 2
        if c == 1 :
            k = int(input('where player 1 wants to put sign : '))
            if k in m :
                print('wrong entry')
                b = b
            else :
                m.append(k)
                l[k] = sign 
                board()
                ch = checkifwin()
                if ch == 1 :
                    print('player 1 won the game')
                    break 
                elif ch == 0 :
                    b = b + 1
        elif c == 2  :  
            k = int(input('where player 2 wants to put sign : '))
            if k in m :
                print('wrong entry')
                b = b
            else :
                m.append(k)
                l[k] = othersign 
                board()
                checkifwin()
                if ch == 1 :
                    print('player 2 won the game')
                    break 
                elif ch == 0 :
                    b = b + 1
    tiktok()

# %%
tiktok()
# Out:
# do u want to play : yes
# choose your sign x or o : x
# othersign = o
# where player 1 wants to put sign : 1
# x |   |
# _____________
#   |   |
# _____________
#   |   |
# where player 2 wants to put sign : 2
# x | o |
# _____________
#   |   |
# _____________
#   |   |
# where player 1 wants to put sign : 5
# x | o |
# _____________
#   | x |
# _____________
#   |   |
# where player 2 wants to put sign : 3
# x | o | o
# _____________
#   | x |
# _____________
#   |   |
# where player 1 wants to put sign : 9
# x | o | o
# _____________
#   | x |
# _____________
#   |   | x
# player 1 won the game

# %% [markdown]
# ###
